# %% [markdown]
# ## This practice is incomplete as pandas module as gone through a lot of changes

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\dell\Desktop\pandas\ETH_1h.csv")
df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df.loc[0, 'Date'].day_name() # ll give error .so first have to convert in proper formay
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.loc[0, 'Date'].day_name() # ll give error .so first have to convert in proper formay
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d %I-%p')
df.head()
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
df.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
df['Date'].dt.day_name() #dt is function in pandas like str
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df['DayOfWeek'] = df['Date'].dt.day_name()
df.head()
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume  \
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
#
#   DayOfWeek
# 0    Friday
# 1    Friday
# 2    Friday
# 3    Friday
# 4    Friday

# %%
df['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df['Date'].max() - df['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = (df['Date'] >= pd.to_datetime('2019-01-01')) & (df['Date'] < pd.to_datetime('2020-01-01'))
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
df.set_index('Date', inplace=True)
df.head()
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
#
#                     DayOfWeek
# Date
# 2020-03-13 20:00:00    Friday
# 2020-03-13 19:00:00    Friday
# 2020-03-13 18:00:00    Friday
# 2020-03-13 17:00:00    Friday
# 2020-03-13 16:00:00    Friday

# %%
df.loc['2019']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df.loc['2019']
#
# File ~\Desktop\pandas\pandaEnv\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\Desktop\pandas\pandaEnv\Lib\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~\Desktop\pandas\pandaEnv\Lib\site-packages\pandas\core\indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
#    1379 def _get_label(self, label, axis: AxisInt):
# ...

# %%
sd = '2019-01-01' 
ed = '2019-12-31' 
dates = pd.date_range(sd, ed)
df = df[df.index.isin(dates)]
df
# Out:
#             Symbol    Open    High     Low   Close      Volume  DayOfWeek
# Date
# 2019-12-31  ETHUSD  131.10  131.10  130.31  131.03   345342.78    Tuesday
# 2019-12-30  ETHUSD  134.30  134.31  133.01  133.42   504867.25     Monday
# 2019-12-29  ETHUSD  127.91  127.95  127.54  127.69   164546.25     Sunday
# 2019-12-28  ETHUSD  126.23  127.60  125.80  127.38   296532.15   Saturday
# 2019-12-27  ETHUSD  125.49  125.56  125.00  125.21   188992.56     Friday
# ...            ...     ...     ...     ...     ...         ...        ...
# 2019-01-05  ETHUSD  153.24  160.50  153.23  159.43  4907530.32   Saturday
# 2019-01-04  ETHUSD  147.23  147.23  145.14  146.81  1016966.84     Friday
# 2019-01-03  ETHUSD  153.50  154.30  150.74  150.82  2114538.16   Thursday
# 2019-01-02  ETHUSD  139.75  140.78  139.22  139.95  1089071.07  Wednesday
# 2019-01-01  ETHUSD  130.53  131.91  130.48  131.62  1067136.21    Tuesday
#
# [365 rows x 7 columns]

# %%
sd = '2019-01-01' 
ed = '2019-12-31' 
dates = pd.date_range(sd, ed)
df = df[df.index.isin(dates)]
df['Close'].mean()
df['Close'].max()
# Out:
# np.float64(339.07)

# %%
df
# Out:
#             Symbol    Open    High     Low   Close      Volume  DayOfWeek
# Date
# 2019-12-31  ETHUSD  131.10  131.10  130.31  131.03   345342.78    Tuesday
# 2019-12-30  ETHUSD  134.30  134.31  133.01  133.42   504867.25     Monday
# 2019-12-29  ETHUSD  127.91  127.95  127.54  127.69   164546.25     Sunday
# 2019-12-28  ETHUSD  126.23  127.60  125.80  127.38   296532.15   Saturday
# 2019-12-27  ETHUSD  125.49  125.56  125.00  125.21   188992.56     Friday
# ...            ...     ...     ...     ...     ...         ...        ...
# 2019-01-05  ETHUSD  153.24  160.50  153.23  159.43  4907530.32   Saturday
# 2019-01-04  ETHUSD  147.23  147.23  145.14  146.81  1016966.84     Friday
# 2019-01-03  ETHUSD  153.50  154.30  150.74  150.82  2114538.16   Thursday
# 2019-01-02  ETHUSD  139.75  140.78  139.22  139.95  1089071.07  Wednesday
# 2019-01-01  ETHUSD  130.53  131.91  130.48  131.62  1067136.21    Tuesday
#
# [365 rows x 7 columns]

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\dell\Desktop\pandas\ETH_1h.csv")
df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
# sd = '2019-01-01' 
# ed = '2019-12-31' 
# dates = pd.date_range(sd, ed)
# df = df[df.index.isin(dates)]
# df['Close'].mean()
# df['Close'].max()

date = pd.date_range('2019','2019')
df[df.index.isin(date)]
# Out:
# Empty DataFrame
# Columns: [Date, Symbol, Open, High, Low, Close, Volume]
# Index: []

# %%
highs = df['High'].resample('D').max()
highs['2020-01-01']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 highs = df['High'].resample('D').max()
#       2 highs['2020-01-01']
#
# File ~\Desktop\pandas\pandaEnv\Lib\site-packages\pandas\core\generic.py:9771, in NDFrame.resample(self, rule, axis, closed, label, convention, kind, on, level, origin, offset, group_keys)
#    9768 else:
#    9769     convention = "start"
# -> 9771 return get_resampler(
#    9772     cast("Series | DataFrame", self),
#    9773     freq=rule,
#    9774     label=label,
#    9775     closed=closed,
#    9776     axis=axis,
#    9777     kind=kind,
#    9778     convention=convention,
#    9779     key=on,
#    9780     level=level,
#    9781     origin=origin,
#    9782     offset=offset,
#    9783     group_keys=group_keys,
#    9784 )
#
# ...
